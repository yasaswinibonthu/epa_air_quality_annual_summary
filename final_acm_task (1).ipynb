# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import pandas as pd

# %%
air_quality_filepath = '/content/epa_air_quality_annual_summary.csv'

# %%
air_quality_data = pd.read_csv(air_quality_filepath)

# %%
air_quality_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10736 entries, 0 to 10735
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   state_code                        10736 non-null  int64
#  1   county_code                       10736 non-null  int64
#  2   site_num                          10736 non-null  int64
#  3   parameter_code                    10736 non-null  int64
#  4   poc                               10736 non-null  int64
#  5   latitude                          10736 non-null  float64
#  6   longitude                         10736 non-null  float64
#  7   datum                             10736 non-null  object
#  8   parameter_name                    10736 non-null  object
#  9   sample_duration                   10736 non-null  object
#  10  pollutant_standard                2737 non-null   object
#  11  metric_used                       10736 non-null  object
#  12  method_name                       9555 non-null   object
#  13  year                              10736 non-null  int64
#  14  units_of_measure                  10736 non-null  object
#  15  event_type                        10736 non-null  object
#  16  observation_count                 10736 non-null  int64
#  17  observation_percent               10736 non-null  int64
#  18  completeness_indicator            10736 non-null  object
#  19  valid_day_count                   10736 non-null  int64
#  20  required_day_count                10736 non-null  int64
#  21  exceptional_data_count            10736 non-null  int64
#  22  null_data_count                   10736 non-null  int64
#  23  primary_exceedance_count          1993 non-null   float64
#  24  secondary_exceedance_count        1770 non-null   float64
#  25  certification_indicator           10736 non-null  object
#  26  num_obs_below_mdl                 10736 non-null  int64
#  27  arithmetic_mean                   10736 non-null  float64
#  28  arithmetic_standard_dev           10736 non-null  float64
#  29  first_max_value                   10736 non-null  float64
#  30  first_max_datetime                10736 non-null  object
#  31  second_max_value                  10648 non-null  float64
#  32  second_max_datetime               10648 non-null  object
#  33  third_max_value                   10586 non-null  float64
#  34  third_max_datetime                10586 non-null  object
#  35  fourth_max_value                  10526 non-null  float64
#  36  fourth_max_datetime               10526 non-null  object
#  37  first_max_non_overlapping_value   110 non-null    float64
#  38  first_no_max_datetime             110 non-null    object
#  39  second_max_non_overlapping_value  110 non-null    float64
#  40  second_no_max_datetime            110 non-null    object
#  41  ninety_nine_percentile            10736 non-null  float64
#  42  ninety_eight_percentile           10736 non-null  float64
#  43  ninety_five_percentile            10736 non-null  float64
#  44  ninety_percentile                 10736 non-null  float64
#  45  seventy_five_percentile           10736 non-null  float64
#  46  fifty_percentile                  10736 non-null  float64
#  47  ten_percentile                    10736 non-null  float64
#  48  local_site_name                   8714 non-null   object
#  49  address                           10728 non-null  object
#  50  state_name                        10735 non-null  object
#  51  county_name                       10735 non-null  object
#  52  city_name                         8896 non-null   object
#  53  cbsa_name                         9799 non-null   object
#  54  date_of_last_change               10735 non-null  object
# dtypes: float64(19), int64(13), object(23)
# memory usage: 4.5+ MB

# %%
air_quality_data.head()
# Out:
#    state_code  county_code  site_num  parameter_code  poc   latitude  \
# 0          20           57         1           82134    1  37.771964
# 1          18          163        12           42401    1  38.021727
# 2          40           31      9000           88152    1  34.732404
# 3          32            3       561           42601    1  36.163959
# 4          13          127      3001           12154    1  31.185187
#
#     longitude  datum       parameter_name sample_duration  ...  \
# 0 -100.018190  WGS84  Molybdenum PM10 STP         24 HOUR  ...
# 1  -87.569458  WGS84       Sulfur dioxide    3-HR BLK AVG  ...
# 2  -98.713351  WGS84  Phosphorus PM2.5 LC         24 HOUR  ...
# 3 -115.113916  WGS84    Nitric oxide (NO)          1 HOUR  ...
# 4  -81.485166  WGS84   Selenium (TSP) STP         24 HOUR  ...
#
#   seventy_five_percentile fifty_percentile ten_percentile  local_site_name  \
# 0                 0.00000              0.0            0.0       DODGE CITY
# 1                 3.60000              1.3            0.0  Evansville CAAP
# 2                 0.00000              0.0            0.0              NaN
# 3                18.80000              0.9            0.0    Sunrise Acres
# 4                 0.00064              0.0            0.0              NaN
#
#                                 address state_name  county_name   city_name  \
# 0             PUMP STATION 2100 1ST AVE     Kansas         Ford  Dodge City
# 1  425 WEST MILL ROAD/ FIRE STATION #17    Indiana  Vanderburgh  Evansville
# 2                     Wichita Mountains   Oklahoma     Comanche         NaN
# 3                   2501 SUNRISE AVENUE     Nevada        Clark   Las Vegas
# 4             BRUNSWICK COASTAL COLLEGE    Georgia        Glynn   Brunswick
#
#                          cbsa_name  date_of_last_change
# 0                    Dodge City KS           2012-08-11
# 1                 Evansville IN-KY           2013-02-16
# 2                        Lawton OK           2016-02-26
# 3  Las Vegas-Henderson-Paradise NV           2015-03-20
# 4                     Brunswick GA           2015-07-22
#
# [5 rows x 55 columns]

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
plt.figure(figsize=(10,10))
sns.barplot(y=air_quality_data.index,x=air_quality_data["poc"])
# Out:
# <Axes: xlabel='poc'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(y=air_quality_data['state_code'],x = air_quality_data['poc'])
# Out:
# <Axes: xlabel='poc', ylabel='state_code'>

# %%
air_quality_data.columns
# Out:
# Index(['state_code', 'county_code', 'site_num', 'parameter_code', 'poc',
#        'latitude', 'longitude', 'datum', 'parameter_name', 'sample_duration',
#        'pollutant_standard', 'metric_used', 'method_name', 'year',
#        'units_of_measure', 'event_type', 'observation_count',
#        'observation_percent', 'completeness_indicator', 'valid_day_count',
#        'required_day_count', 'exceptional_data_count', 'null_data_count',
#        'primary_exceedance_count', 'secondary_exceedance_count',
#        'certification_indicator', 'num_obs_below_mdl', 'arithmetic_mean',
#        'arithmetic_standard_dev', 'first_max_value', 'first_max_datetime',
#        'second_max_value', 'second_max_datetime', 'third_max_value',
#        'third_max_datetime', 'fourth_max_value', 'fourth_max_datetime',
#        'first_max_non_overlapping_value', 'first_no_max_datetime',
#        'second_max_non_overlapping_value', 'second_no_max_datetime',
#        'ninety_nine_percentile', 'ninety_eight_percentile',
#        'ninety_five_percentile', 'ninety_percentile',
#        'seventy_five_percentile', 'fifty_percentile', 'ten_percentile',
#        'local_site_name', 'address', 'state_name', 'county_name', 'city_name',
#        'cbsa_name', 'date_of_last_change'],
#       dtype='object')

# %%
y = air_quality_data.poc

# %%
air_quality_features = [ 'state_code','county_code','site_num','parameter_code']

# %%
X = air_quality_data[air_quality_features]

# %%
X.describe()
# Out:
#          state_code   county_code      site_num  parameter_code
# count  10736.000000  10736.000000  10736.000000    10736.000000
# mean      28.392977     83.577496   1072.416077    57711.281762
# std       17.169380     94.399516   2262.990367    23461.152452
# min        1.000000      1.000000      1.000000    11101.000000
# 25%       12.000000     25.000000      7.000000    43242.000000
# 50%       27.000000     61.000000     29.000000    45207.000000
# 75%       42.000000    111.000000   1004.000000    88101.000000
# max       80.000000    901.000000   9997.000000    88503.000000

# %%
from sklearn.tree import DecisionTreeRegressor
air_quality_model = DecisionTreeRegressor(random_state=1)
air_quality_model.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print("Making Predictions for the poc fot the 1st five cases")
print(X.head())
print("The Predictions are")
print(air_quality_model.predict(X.head()))
# Out:
# Making Predictions for the poc fot the 1st five cases
#    state_code  county_code  site_num  parameter_code
# 0          20           57         1           82134
# 1          18          163        12           42401
# 2          40           31      9000           88152
# 3          32            3       561           42601
# 4          13          127      3001           12154
# The Predictions are
# [1. 1. 1. 1. 1.]

# %%
from sklearn.metrics import mean_absolute_error
predicted_air_quality = air_quality_model.predict(X)
mean_absolute_error(y,predicted_air_quality)
# Out:
# 0.03793467461500248

# %%
from sklearn.model_selection import train_test_split

# %%
from tables.group import TransactionGroupG
train_X,val_X,train_y,val_y = train_test_split(X,y,random_state=0)
air_quality_model=DecisionTreeRegressor()
air_quality_model.fit(train_X,train_y)
# Out:
# DecisionTreeRegressor()

# %%
val_predictions = air_quality_model.predict(val_X)
print(mean_absolute_error(val_y,val_predictions))
# Out:
# 0.8966095380029806

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
def get_mae(max_leaf_nodes,train_X,val_X,train_y,val_y):
 model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes,random_state=0)
 model.fit(train_X,train_y)
 preds_val = model.predict(val_X)
 mae = mean_absolute_error(val_y,preds_val)
 return(mae)

# %%
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  1
# Max leaf nodes: 50  		 Mean Absolute Error:  1
# Max leaf nodes: 500  		 Mean Absolute Error:  0
# Max leaf nodes: 5000  		 Mean Absolute Error:  0

# %%
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  1
# Max leaf nodes: 50  		 Mean Absolute Error:  1
# Max leaf nodes: 500  		 Mean Absolute Error:  0
# Max leaf nodes: 5000  		 Mean Absolute Error:  0

# %%
from tensorflow import keras
from tensorflow.keras import layers
air_quality_model = keras.Sequential([
    layers.Dense(units=1, input_shape=[3])
])

# %%
from tensorflow import keras
from tensorflow.keras import layers

air_quality_model = keras.Sequential([
    layers.Dense(units=4, activation='relu', input_shape=[2]),
    layers.Dense(units=3, activation='relu'),
    layers.Dense(units=1),
])

# %%
from tensorflow import keras
from tensorflow.keras import layers

air_quality_model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[4]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

# %%
air_quality_model.compile(
    optimizer='adam',
    loss='mae',
)

# %%
print(train_X.shape)
# Out:
# (8052, 4)

# %%
history = air_quality_model.fit(
    train_X, train_y,
    validation_data=(val_X, val_y),
    batch_size=256,
    epochs=100,
)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 7s 70ms/step - loss: 1554.2222 - val_loss: 137.1202
# Epoch 2/100
# 32/32 [==============================] - 2s 56ms/step - loss: 130.3084 - val_loss: 8.6402
# Epoch 3/100
# 32/32 [==============================] - 2s 54ms/step - loss: 76.1225 - val_loss: 5.7032
# Epoch 4/100
# 32/32 [==============================] - 2s 56ms/step - loss: 29.3008 - val_loss: 11.5268
# Epoch 5/100
# 32/32 [==============================] - 2s 66ms/step - loss: 36.6372 - val_loss: 23.5072
# Epoch 6/100
# 32/32 [==============================] - 3s 93ms/step - loss: 30.9731 - val_loss: 67.0246
# Epoch 7/100
# 32/32 [==============================] - 2s 54ms/step - loss: 29.3390 - val_loss: 41.3158
# Epoch 8/100
# 32/32 [==============================] - 1s 29ms/step - loss: 19.2609 - val_loss: 5.2805
# Epoch 9/100
# 32/32 [==============================] - 1s 29ms/step - loss: 3.8178 - val_loss: 2.7469
# Epoch 10/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.7831 - val_loss: 1.8457
# Epoch 11/100
# 32/32 [==============================] - 1s 28ms/step - loss: 2.0537 - val_loss: 1.7396
# Epoch 12/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.9039 - val_loss: 1.6999
# Epoch 13/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.7477 - val_loss: 1.6285
# Epoch 14/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.5359 - val_loss: 1.6427
# Epoch 15/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4993 - val_loss: 1.5503
# Epoch 16/100
# 32/32 [==============================] - 1s 34ms/step - loss: 1.4683 - val_loss: 1.5519
# Epoch 17/100
# 32/32 [==============================] - 2s 48ms/step - loss: 1.4659 - val_loss: 1.5407
# Epoch 18/100
# 32/32 [==============================] - 1s 46ms/step - loss: 1.4568 - val_loss: 1.5408
# Epoch 19/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4649 - val_loss: 1.5306
# Epoch 20/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4383 - val_loss: 1.5047
# Epoch 21/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4307 - val_loss: 1.5203
# Epoch 22/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4257 - val_loss: 1.4927
# Epoch 23/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4282 - val_loss: 1.5334
# Epoch 24/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4489 - val_loss: 1.5221
# Epoch 25/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4491 - val_loss: 1.4946
# Epoch 26/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4193 - val_loss: 1.4844
# Epoch 27/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4084 - val_loss: 1.4807
# Epoch 28/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4122 - val_loss: 1.4921
# Epoch 29/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4144 - val_loss: 1.4907
# Epoch 30/100
# 32/32 [==============================] - 2s 52ms/step - loss: 1.4087 - val_loss: 1.4801
# Epoch 31/100
# 32/32 [==============================] - 1s 47ms/step - loss: 1.4025 - val_loss: 1.4862
# Epoch 32/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4027 - val_loss: 1.4833
# Epoch 33/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4068 - val_loss: 1.4767
# Epoch 34/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4042 - val_loss: 1.4936
# Epoch 35/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.3998 - val_loss: 1.4896
# Epoch 36/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4066 - val_loss: 1.5062
# Epoch 37/100
# 32/32 [==============================] - 1s 31ms/step - loss: 2.8046 - val_loss: 5.1065
# Epoch 38/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.5884 - val_loss: 1.4954
# Epoch 39/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4093 - val_loss: 1.4785
# Epoch 40/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.3990 - val_loss: 1.4876
# Epoch 41/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4083 - val_loss: 1.4899
# Epoch 42/100
# 32/32 [==============================] - 1s 36ms/step - loss: 1.4006 - val_loss: 1.4861
# Epoch 43/100
# 32/32 [==============================] - 1s 46ms/step - loss: 1.4012 - val_loss: 1.4813
# Epoch 44/100
# 32/32 [==============================] - 1s 46ms/step - loss: 1.4029 - val_loss: 1.4770
# Epoch 45/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4025 - val_loss: 1.4726
# Epoch 46/100
# 32/32 [==============================] - 1s 31ms/step - loss: 1.4007 - val_loss: 1.4955
# Epoch 47/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4079 - val_loss: 1.4816
# Epoch 48/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.3987 - val_loss: 1.4793
# Epoch 49/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4003 - val_loss: 1.4718
# Epoch 50/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4006 - val_loss: 1.4764
# Epoch 51/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4062 - val_loss: 1.4746
# Epoch 52/100
# 32/32 [==============================] - 1s 31ms/step - loss: 1.4086 - val_loss: 1.4826
# Epoch 53/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4050 - val_loss: 1.4876
# Epoch 54/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4015 - val_loss: 1.4768
# Epoch 55/100
# 32/32 [==============================] - 1s 37ms/step - loss: 1.4006 - val_loss: 1.4730
# Epoch 56/100
# 32/32 [==============================] - 2s 47ms/step - loss: 1.4051 - val_loss: 1.4756
# Epoch 57/100
# 32/32 [==============================] - 1s 43ms/step - loss: 1.4010 - val_loss: 1.4734
# Epoch 58/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4009 - val_loss: 1.4720
# Epoch 59/100
# 32/32 [==============================] - 1s 27ms/step - loss: 1.4055 - val_loss: 1.4698
# Epoch 60/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4014 - val_loss: 1.4709
# Epoch 61/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4008 - val_loss: 1.4703
# Epoch 62/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4008 - val_loss: 1.4703
# Epoch 63/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4014 - val_loss: 1.4809
# Epoch 64/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4022 - val_loss: 1.4740
# Epoch 65/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4018 - val_loss: 1.4773
# Epoch 66/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4013 - val_loss: 1.4734
# Epoch 67/100
# 32/32 [==============================] - 1s 31ms/step - loss: 1.4047 - val_loss: 1.4710
# Epoch 68/100
# 32/32 [==============================] - 1s 38ms/step - loss: 1.4020 - val_loss: 1.4695
# Epoch 69/100
# 32/32 [==============================] - 2s 49ms/step - loss: 1.4002 - val_loss: 1.4712
# Epoch 70/100
# 32/32 [==============================] - 1s 43ms/step - loss: 1.4016 - val_loss: 1.4709
# Epoch 71/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4011 - val_loss: 1.4742
# Epoch 72/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4013 - val_loss: 1.4693
# Epoch 73/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4008 - val_loss: 1.4729
# Epoch 74/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4009 - val_loss: 1.4722
# Epoch 75/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4001 - val_loss: 1.4726
# Epoch 76/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4016 - val_loss: 1.4736
# Epoch 77/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4015 - val_loss: 1.4746
# Epoch 78/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4013 - val_loss: 1.4742
# Epoch 79/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4006 - val_loss: 1.4705
# Epoch 80/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4013 - val_loss: 1.4728
# Epoch 81/100
# 32/32 [==============================] - 1s 40ms/step - loss: 1.4010 - val_loss: 1.4701
# Epoch 82/100
# 32/32 [==============================] - 2s 47ms/step - loss: 1.4027 - val_loss: 1.4722
# Epoch 83/100
# 32/32 [==============================] - 1s 40ms/step - loss: 1.4053 - val_loss: 1.4742
# Epoch 84/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.4032 - val_loss: 1.4777
# Epoch 85/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4013 - val_loss: 1.4716
# Epoch 86/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4008 - val_loss: 1.4734
# Epoch 87/100
# 32/32 [==============================] - 1s 31ms/step - loss: 1.4004 - val_loss: 1.4706
# Epoch 88/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4008 - val_loss: 1.4751
# Epoch 89/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4022 - val_loss: 1.4723
# Epoch 90/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4001 - val_loss: 1.4720
# Epoch 91/100
# 32/32 [==============================] - 1s 28ms/step - loss: 1.4003 - val_loss: 1.4759
# Epoch 92/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.3998 - val_loss: 1.4705
# Epoch 93/100
# 32/32 [==============================] - 1s 34ms/step - loss: 1.4022 - val_loss: 1.4700
# Epoch 94/100
# 32/32 [==============================] - 2s 67ms/step - loss: 1.4016 - val_loss: 1.4707
# Epoch 95/100
# 32/32 [==============================] - 1s 46ms/step - loss: 1.4001 - val_loss: 1.4710
# Epoch 96/100
# 32/32 [==============================] - 1s 31ms/step - loss: 1.4003 - val_loss: 1.4703
# Epoch 97/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.3997 - val_loss: 1.4717
# Epoch 98/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4010 - val_loss: 1.4715
# Epoch 99/100
# 32/32 [==============================] - 1s 29ms/step - loss: 1.4000 - val_loss: 1.4734
# Epoch 100/100
# 32/32 [==============================] - 1s 30ms/step - loss: 1.3993 - val_loss: 1.4732

# %%
import pandas as pd
history_df = pd.DataFrame(history.history)
history_df['loss'].plot();

# %%
air_quality_model = keras.Sequential([
    layers.Dense(16, activation='relu'),
    layers.Dense(1),
])

wider = keras.Sequential([
    layers.Dense(32, activation='relu'),
    layers.Dense(1),
])

deeper = keras.Sequential([
    layers.Dense(16, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1),
])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    min_delta=0.001, 
    patience=20, 
    restore_best_weights=True,
)

# %%
from tensorflow import keras
from tensorflow.keras import layers, callbacks

early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, 
    patience=20, 
    restore_best_weights=True,
)

air_quality_model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[4]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])
air_quality_model.compile(
    optimizer='adam',
    loss='mae',
)

# %% [markdown]
# loss and accuracy curve

# %%
history = air_quality_model.fit(
    train_X, train_y,
    validation_data=(val_X, val_y),
    batch_size=256,
    epochs=500,
    callbacks=[early_stopping],
    verbose=0, 
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))
# Out:
# Minimum validation loss: 1.4698541164398193

# %%
from tensorflow import keras
from tensorflow.keras import layers

air_quality_model = keras.Sequential([
    layers.Dense(1024, activation='relu', input_shape=[4]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
air_quality_model.compile(
    optimizer='adam',
    loss='mae',
)

history = air_quality_model.fit(
    train_X, train_y,
    validation_data=(val_X,val_y),
    batch_size=256,
    epochs=100,
    verbose=0,
)



history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();
